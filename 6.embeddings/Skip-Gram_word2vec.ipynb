# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
from math import sqrt
from random import random

t = 1e-5
counts = Counter(words)
freqs = [ counts[int_to_vocab[i]]/len(words) for i in int_words ]
keep_probs = [ sqrt(t/f) for f in freqs  ]

train_words = [ w for i,w in enumerate(int_words) if random() <= keep_probs[i] ]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import randint

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    radius = randint(1,window_size)
    start = max(0, idx - radius)
    end = min(idx + radius, len(words)-1)
    #remove duplicates!
    return list(set(words[start : end]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
# <CUSTOM>
import random
# </CUSTOM>

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6410 0.4524 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.4907 0.3932 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3017 0.3716 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3865 0.4019 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2637 0.3700 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2445 0.3826 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2183 0.4439 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1883 0.4196 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.1057 0.4376 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.0498 0.4088 sec/batch
# Nearest to the: philadelphia, cor, salut, strongpoints, grace, shattering, possibly, chubut,
# Nearest to about: natures, bengali, helices, ghats, guinea, increase, barbara, pain,
# Nearest to two: jun, daikaiju, alphonso, dutton, andrewes, ozone, labatt, ryder,
# Nearest to they: ranged, seasonally, margravate, spiraling, basaltic, jarkko, local, vortex,
# Nearest to th: morph, kievan, rebuked, regarded, arse, minded, auroral, boingo,
# Nearest to d: victoria, sniping, androgeus, kauravas, fagatogo, newstead, diode, mae,
# Nearest to war: springer, internationally, anniversary, benz, secede, christen, refinement, linings,
# Nearest to when: incongruous, gibbons, gundam, thetis, spangled, cs, comforter, bolus,
# Nearest to engineering: flyweight, argumentation, fame, athletes, warhammer, picardy, melted, tugboat,
# Nearest to stage: deluge, reggaeton, aminoacids, rabin, repulsion, amputated, millar, noticed,
# Nearest to additional: flit, deutsch, rashad, combine, ear, deprogrammings, boulez, psychiatric,
# Nearest to http: pac, villages, s, lfdan, voiceover, yea, gel, saracens,
# Nearest to taking: indira, poset, detractors, supposedly, gilt, filesystem, leningrad, boeotian,
# Nearest to mean: repealed, convenient, supreme, cassell, boy, shareware, bingu, matilda,
# Nearest to cost: signal, nigger, uncontrolled, beggars, erinyes, sympathetically, meanwhile, standards,
# Nearest to ice: stylistic, gauze, pentafluoride, benny, cooperates, december, entrepreneur, leonard,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.0974 0.4774 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0512 0.4732 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0072 0.4756 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9268 0.5078 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8890 0.4816 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8571 0.4418 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7842 0.3597 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7671 0.3646 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7101 0.3626 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7295 0.3645 sec/batch
# Nearest to the: philadelphia, possibly, salut, cor, grace, sword, strongpoints, explosions,
# Nearest to about: increase, natures, guinea, general, from, pain, said, curious,
# Nearest to two: jun, ryder, ozone, dutton, reduce, assistant, f, alphonso,
# Nearest to they: ranged, local, seasonally, margravate, hispanic, spiraling, broken, vortex,
# Nearest to th: morph, regarded, use, average, cycles, movements, page, kievan,
# Nearest to d: victoria, androgeus, diode, fagatogo, mae, chicxulub, sniping, theologian,
# Nearest to war: internationally, springer, anniversary, secede, refinement, e, encarta, abroad,
# Nearest to when: incongruous, cs, excalibur, route, these, surrogate, until, grouped,
# Nearest to engineering: fame, flyweight, argumentation, athletes, melted, venezuela, event, warhammer,
# Nearest to stage: aminoacids, repulsion, yet, millar, deluge, avalanche, invalid, rabin,
# Nearest to additional: flit, deutsch, ear, rashad, combine, own, humiliation, hunt,
# Nearest to http: s, pac, villages, voiceover, calico, saracens, gel, dedicated,
# Nearest to taking: supposedly, possibly, currency, indira, detractors, leningrad, s, withdrawals,
# Nearest to mean: convenient, supreme, repealed, boy, cooper, cassell, bingu, misfired,
# Nearest to cost: signal, nigger, standards, study, uncontrolled, meanwhile, beggars, flare,
# Nearest to ice: stylistic, gauze, pentafluoride, december, benny, skeletal, weapon, cooperates,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6676 0.3647 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6197 0.3415 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.5837 0.3226 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.5660 0.3739 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.5150 0.3842 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5112 0.4237 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5001 0.4237 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.4842 0.4654 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.4671 0.4440 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.4561 0.4201 sec/batch
# Nearest to the: philadelphia, salut, grace, possibly, venture, cor, explosions, sword,
# Nearest to about: barbara, curious, guinea, increase, natures, negotiated, pain, helices,
# Nearest to two: assistant, jun, dutton, alphonso, seven, f, pietro, indistinguishable,
# Nearest to they: ranged, seasonally, local, hispanic, margravate, promulgated, broken, continuous,
# Nearest to th: defenders, morph, page, minded, cycles, regarded, kievan, movements,
# Nearest to d: victoria, mitchell, fagatogo, diode, mae, androgeus, theologian, icons,
# Nearest to war: internationally, springer, anniversary, secede, encarta, netherlands, abroad, eased,
# Nearest to when: incongruous, gundam, excalibur, identifier, dirt, gibbons, surrogate, pact,
# Nearest to engineering: fame, argumentation, flyweight, melted, athletes, mixture, closing, venezuela,
# Nearest to stage: repulsion, noticed, invalid, aminoacids, yet, deluge, avalanche, chef,
# Nearest to additional: deutsch, flit, combine, ear, humiliation, own, rashad, psychiatric,
# Nearest to http: pac, s, dedicated, saracens, voiceover, www, trust, yea,
# Nearest to taking: currency, detractors, supposedly, indira, filesystem, possibly, workers, vendors,
# Nearest to mean: convenient, repealed, supreme, boy, cassell, cooper, detection, nobility,
# Nearest to cost: signal, nigger, hollywood, uncontrolled, beggars, standards, study, buttons,
# Nearest to ice: stylistic, gauze, pentafluoride, december, weapon, leonard, skeletal, benny,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.4569 0.4633 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.4470 0.4848 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.4215 0.4541 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.3997 0.4669 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4316 0.5266 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.3939 0.4397 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.3828 0.5333 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.3994 0.4538 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.3713 0.4021 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.3497 0.4928 sec/batch
# Nearest to the: philadelphia, salut, shattering, grace, dam, explosions, showdown, sword,
# Nearest to about: curious, natures, ghats, negotiated, guinea, barbara, increase, underground,
# Nearest to two: alphonso, dutton, zero, seven, assistant, jun, annette, andrewes,
# Nearest to they: ranged, seasonally, margravate, hispanic, specialization, local, vortex, promulgated,
# Nearest to th: defenders, drummers, morph, page, kievan, cycles, hanson, nebula,
# Nearest to d: theologian, victoria, physicist, mae, comedian, frontiersman, mitchell, newstead,
# Nearest to war: internationally, anniversary, springer, secede, encarta, monuments, netherlands, nfl,
# Nearest to when: incongruous, gundam, gibbons, excalibur, bolus, identifier, updating, dynasties,
# Nearest to engineering: argumentation, flyweight, melted, athletes, fame, closing, incorporates, warhammer,
# Nearest to stage: repulsion, deluge, noticed, rabin, invalid, aminoacids, avalanche, chef,
# Nearest to additional: deutsch, flit, combine, humiliation, ear, psychiatric, rashad, own,
# Nearest to http: pac, s, www, dedicated, saracens, voiceover, calico, yea,
# Nearest to taking: detractors, currency, poset, filesystem, workers, possibly, supposedly, indira,
# Nearest to mean: convenient, cassell, repealed, salted, detection, shareware, revert, cooper,
# Nearest to cost: signal, nigger, beggars, uncontrolled, hollywood, abdurrahman, standards, buttons,
# Nearest to ice: stylistic, gauze, pentafluoride, weapon, leonard, cooperates, astronomers, skeletal,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.3434 0.4605 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.3693 0.4249 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.2847 0.4230 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.3199 0.4311 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3348 0.4625 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.3118 0.4539 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.2785 0.3468 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.2302 0.4312 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.2087 0.4644 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.1870 0.5136 sec/batch
# Nearest to the: philadelphia, shattering, dispelled, salut, chubut, explosions, dam, cor,
# Nearest to about: curious, ghats, unforgettable, increase, natures, negotiated, guinea, helices,
# Nearest to two: zero, seven, alphonso, dutton, jun, five, assistant, pietro,
# Nearest to they: ranged, seasonally, margravate, endorsements, specialization, ganga, hispanic, cigar,
# Nearest to th: defenders, century, drummers, kievan, morph, sira, nebula, hanson,
# Nearest to d: physicist, theologian, comedian, victoria, singer, mae, activist, frontiersman,
# Nearest to war: internationally, secede, anniversary, netherlands, monuments, congolese, nfl, benno,
# Nearest to when: gundam, incongruous, gibbons, bolus, updating, comforter, excalibur, dynasties,
# Nearest to engineering: argumentation, flyweight, melted, closing, incorporates, mixture, warhammer, athletes,
# Nearest to stage: repulsion, avalanche, noticed, aminoacids, rabin, deluge, millar, chef,
# Nearest to additional: deutsch, flit, ear, humiliation, combine, psychiatric, rashad, cernunnos,
# Nearest to http: www, pac, s, html, dedicated, newman, yea, saracens,
# Nearest to taking: poset, filesystem, detractors, currency, indira, awk, workers, supposedly,
# Nearest to mean: convenient, cassell, salted, revert, semper, shareware, bingu, conserved,
# Nearest to cost: signal, nigger, beggars, thalamus, buttons, uncontrolled, abdurrahman, debris,
# Nearest to ice: stylistic, pentafluoride, weapon, gauze, cooperates, leonard, skeletal, proof,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.1861 0.5290 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.2096 0.4529 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.1483 0.4266 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.2176 0.4192 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.1802 0.3811 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.1934 0.4797 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.1432 0.4980 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.0962 0.5159 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.1183 0.4252 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.0975 0.3496 sec/batch
# Nearest to the: dispelled, shattering, explosions, philadelphia, chubut, salut, dam, showdown,
# Nearest to about: ghats, curious, increase, unforgettable, wettin, imprecise, helices, pain,
# Nearest to two: zero, seven, five, dutton, jun, alphonso, algorithms, total,
# Nearest to they: ranged, seasonally, specialization, margravate, endorsements, shaoqi, equaled, ganga,
# Nearest to th: century, defenders, kievan, drummers, sira, morph, rebuilt, cycles,
# Nearest to d: theologian, physicist, victoria, comedian, mae, frontiersman, heinrich, activist,
# Nearest to war: secede, internationally, congolese, anniversary, restored, monuments, trojan, netherlands,
# Nearest to when: gundam, incongruous, bolus, gibbons, comforter, excalibur, updating, unlit,
# Nearest to engineering: flyweight, argumentation, closing, melted, mixture, confounded, warhammer, incorporates,
# Nearest to stage: avalanche, noticed, repulsion, millar, aminoacids, deluge, religiosity, bushman,
# Nearest to additional: deutsch, flit, ear, humiliation, psychiatric, combine, rashad, cernunnos,
# Nearest to http: www, html, pac, newman, s, dedicated, yea, tutorials,
# Nearest to taking: poset, filesystem, detractors, awk, currency, indira, supposedly, vendors,
# Nearest to mean: convenient, cassell, salted, semper, bingu, conserved, detection, antisymmetric,
# Nearest to cost: signal, nigger, beggars, thalamus, buttons, pace, standards, flare,
# Nearest to ice: stylistic, pentafluoride, weapon, gauze, cooperates, opportune, rgb, skeletal,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.1270 0.3629 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.1132 0.4094 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.1391 0.4145 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.1092 0.3577 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.1027 0.3778 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.1143 0.3912 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0742 0.3853 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.1009 0.4108 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.1119 0.4037 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.0759 0.3664 sec/batch
# Nearest to the: dispelled, chubut, shattering, explosions, salut, philadelphia, strongpoints, dam,
# Nearest to about: curious, ghats, unforgettable, helices, increase, wettin, sudden, imprecise,
# Nearest to two: zero, seven, five, andrewes, dutton, jun, algorithms, three,
# Nearest to they: ranged, seasonally, specialization, margravate, local, endorsements, equaled, shaoqi,
# Nearest to th: century, defenders, kievan, sira, phoenician, drummers, deceitful, morph,
# Nearest to d: theologian, physicist, mae, victoria, comedian, frontiersman, heinrich, newstead,
# Nearest to war: secede, congolese, internationally, trojan, restored, anniversary, ties, abroad,
# Nearest to when: bolus, gundam, incongruous, gibbons, comforter, excalibur, marcian, unlit,
# Nearest to engineering: argumentation, flyweight, confounded, closing, melted, mixture, incorporates, warhammer,
# Nearest to stage: millar, noticed, repulsion, religiosity, blonde, avalanche, aminoacids, deluge,
# Nearest to additional: flit, deutsch, ear, humiliation, psychiatric, rashad, wcw, infertility,
# Nearest to http: www, html, pac, archive, newman, org, com, tutorials,
# Nearest to taking: poset, filesystem, awk, detractors, currency, breaker, faro, vendors,
# Nearest to mean: convenient, semper, cassell, salted, antisymmetric, conserved, bingu, isn,
# Nearest to cost: signal, nigger, beggars, pace, thalamus, buttons, standards, debris,
# Nearest to ice: stylistic, gauze, pentafluoride, weapon, cooperates, opportune, underwater, rgb,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.0823 0.3952 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0634 0.3528 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.0335 0.3774 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.0681 0.3767 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.0848 0.3670 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.0476 0.4706 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.0832 0.3767 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.0745 0.3425 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.0086 0.3518 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.0392 0.3624 sec/batch
# Nearest to the: dispelled, chubut, shattering, explosions, salut, dam, infinitum, exhortations,
# Nearest to about: curious, ghats, increase, limassol, unforgettable, indiscernibles, hardpoints, sudden,
# Nearest to two: zero, seven, five, andrewes, three, four, dutton, algorithms,
# Nearest to they: ranged, seasonally, margravate, specialization, endorsements, shaoqi, local, ganga,
# Nearest to th: century, defenders, sira, kievan, phoenician, deceitful, drummers, rebuilt,
# Nearest to d: physicist, theologian, victoria, frontiersman, mae, guglielmo, yves, comedian,
# Nearest to war: secede, congolese, restored, allies, internationally, ties, abroad, trojan,
# Nearest to when: bolus, incongruous, gibbons, gundam, excalibur, lode, marcian, unlit,
# Nearest to engineering: argumentation, flyweight, confounded, incorporates, closing, technologies, warhammer, tuong,
# Nearest to stage: noticed, millar, blonde, religiosity, repulsion, chef, avalanche, aminoacids,
# Nearest to additional: flit, deutsch, ear, humiliation, psychiatric, wcw, rashad, cernunnos,
# Nearest to http: www, html, pac, archive, tutorials, org, com, edu,
# Nearest to taking: poset, filesystem, detractors, awk, currency, workers, faro, totalitarian,
# Nearest to mean: convenient, antisymmetric, conserved, salted, cassell, isn, semper, exp,
# Nearest to cost: signal, pace, nigger, beggars, thalamus, buttons, enables, companies,
# Nearest to ice: stylistic, pentafluoride, gauze, opportune, weapon, underwater, rgb, octopussy,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.0418 0.3733 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.9763 0.3830 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.0272 0.4285 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.0457 0.4527 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.0579 0.3616 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 3.9559 0.4179 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 3.9960 0.3702 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.0306 0.3706 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.9123 0.3806 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 3.9987 0.3842 sec/batch
# Nearest to the: dispelled, chubut, shattering, explosions, exhortations, bamileke, infinitum, strongpoints,
# Nearest to about: curious, ghats, hardpoints, rossington, limassol, imprecise, helices, indiscernibles,
# Nearest to two: zero, five, seven, dutton, andrewes, four, three, total,
# Nearest to they: ranged, margravate, seasonally, specialization, shaoqi, endorsements, ganga, punter,
# Nearest to th: century, sira, defenders, kievan, phoenician, deceitful, drummers, urban,
# Nearest to d: theologian, physicist, victoria, botanist, frontiersman, comedian, mae, heinrich,
# Nearest to war: secede, congolese, allies, ties, restored, imperialists, trojan, internationally,
# Nearest to when: bolus, incongruous, excalibur, gundam, gibbons, marcian, lode, thetis,
# Nearest to engineering: argumentation, flyweight, confounded, technologies, incorporates, tuong, closing, warhammer,
# Nearest to stage: blonde, chef, noticed, millar, amputated, avalanche, aminoacids, bushman,
# Nearest to additional: flit, deutsch, humiliation, ear, psychiatric, wcw, rashad, cernunnos,
# Nearest to http: www, html, org, tutorials, archive, com, pac, edu,
# Nearest to taking: poset, filesystem, awk, currency, detractors, faro, workers, lilia,
# Nearest to mean: convenient, antisymmetric, conserved, isn, salted, exp, substituting, semper,
# Nearest to cost: signal, pace, beggars, nigger, buttons, thalamus, enables, debris,
# Nearest to ice: stylistic, underwater, weapon, opportune, pentafluoride, gauze, octopussy, pantomime,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 3.9762 0.4102 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.0042 0.4894 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.0189 0.2685 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.9509 0.5004 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.9124 0.4598 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.9316 0.4524 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.9083 0.4982 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.9309 0.5120 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.9240 0.4897 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.8773 0.5141 sec/batch
# Nearest to the: dispelled, chubut, shattering, infinitum, rub, explosions, dam, bamileke,
# Nearest to about: curious, ghats, watered, rossington, hardpoints, limassol, unforgettable, increase,
# Nearest to two: zero, seven, five, andrewes, dutton, four, three, jun,
# Nearest to they: ranged, endorsements, seasonally, margravate, specialization, shaoqi, ganga, ancestral,
# Nearest to th: century, sira, kievan, phoenician, deceitful, defenders, rd, bronfman,
# Nearest to d: theologian, physicist, botanist, frontiersman, victoria, mae, yves, heinrich,
# Nearest to war: secede, congolese, imperialists, allies, trojan, internationally, communists, ties,
# Nearest to when: bolus, incongruous, gundam, excalibur, marcian, gibbons, lode, thetis,
# Nearest to engineering: argumentation, flyweight, confounded, tuong, incorporates, technologies, sculley, renewable,
# Nearest to stage: blonde, noticed, amputated, millar, chef, armament, avalanche, repulsion,
# Nearest to additional: deutsch, flit, humiliation, wcw, ear, onshore, cernunnos, psychiatric,
# Nearest to http: www, html, org, tutorials, com, edu, archive, htm,
# Nearest to taking: poset, filesystem, awk, detractors, lilia, faro, precipitates, totalitarian,
# Nearest to mean: antisymmetric, convenient, isn, conserved, salted, exp, sample, computable,
# Nearest to cost: pace, signal, beggars, buttons, thalamus, companies, enables, nigger,
# Nearest to ice: stylistic, underwater, opportune, pentafluoride, pantomime, jaguars, weapon, octopussy,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.9261 0.4445 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.8952 0.4279 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.9065 0.4485 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.8465 0.4330 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.8554 0.4362 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.8659 0.4341 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.8223 0.4341 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8571 0.4467 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.9142 0.4298 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.8367 0.4277 sec/batch
# Nearest to the: dispelled, chubut, infinitum, shattering, bamileke, beached, dam, explosions,
# Nearest to about: ghats, curious, rossington, watered, hardpoints, increase, unforgettable, helices,
# Nearest to two: zero, andrewes, seven, five, four, three, dutton, algorithms,
# Nearest to they: ranged, endorsements, margravate, seasonally, local, specialization, shaoqi, ancestral,
# Nearest to th: century, sira, kievan, phoenician, deceitful, rd, defenders, bronfman,
# Nearest to d: theologian, physicist, victoria, frontiersman, guglielmo, mae, kirchhoff, veitch,
# Nearest to war: secede, allies, congolese, imperialists, communists, warfare, wars, trojan,
# Nearest to when: bolus, excalibur, incongruous, gundam, marcian, lode, thetis, unlit,
# Nearest to engineering: argumentation, flyweight, confounded, technologies, renewable, incorporates, tuong, iau,
# Nearest to stage: noticed, blonde, amputated, chef, millar, armament, gssps, deluge,
# Nearest to additional: flit, deutsch, wcw, humiliation, wikis, amperes, amps, anconia,
# Nearest to http: www, html, org, com, edu, tutorials, archive, htm,
# Nearest to taking: poset, filesystem, awk, faro, precipitates, vaughan, lilia, breaker,
# Nearest to mean: antisymmetric, isn, convenient, computable, conserved, cassell, sample, semper,
# Nearest to cost: pace, signal, beggars, buttons, thalamus, nigger, enables, externally,
# Nearest to ice: stylistic, underwater, opportune, pentafluoride, jaguars, pole, slugger, vapor,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.8676 0.4361 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.9123 0.4402 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.8462 0.5041 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.8544 0.5272 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.8806 0.5370 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.9106 0.5013 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.8760 0.4345 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.8472 0.3587 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.8272 0.3685 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.8682 0.3316 sec/batch
# Nearest to the: dispelled, infinitum, chubut, bamileke, shattering, philadelphia, exhortations, explosions,
# Nearest to about: curious, ghats, rossington, watered, increase, limassol, proclus, hardpoints,
# Nearest to two: zero, andrewes, four, five, seven, three, dutton, jun,
# Nearest to they: ranged, margravate, specialization, seasonally, ancestral, shaoqi, endorsements, ganga,
# Nearest to th: century, sira, kievan, deceitful, boingo, rd, cycles, phoenician,
# Nearest to d: theologian, physicist, guglielmo, botanist, frontiersman, mae, victoria, kirchhoff,
# Nearest to war: secede, allies, imperialists, communists, trojan, wars, congolese, warfare,
# Nearest to when: bolus, incongruous, excalibur, gundam, marcian, thetis, lode, snout,
# Nearest to engineering: argumentation, confounded, renewable, flyweight, incorporates, technologies, nanotechnology, tuong,
# Nearest to stage: noticed, amputated, blonde, millar, chef, gssps, deluge, rabin,
# Nearest to additional: deutsch, flit, humiliation, wcw, wikis, amps, aloud, anconia,
# Nearest to http: www, html, org, edu, com, tutorials, htm, archive,
# Nearest to taking: poset, filesystem, awk, breaker, vaughan, precipitates, inhibitors, faro,
# Nearest to mean: antisymmetric, isn, convenient, computable, presaging, breaded, cassell, nootka,
# Nearest to cost: pace, beggars, signal, buttons, externally, thalamus, uncontrolled, hovering,
# Nearest to ice: underwater, stylistic, vapor, pentafluoride, pole, jaguars, opportune, vegetables,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.8880 0.3414 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8781 0.3561 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.8869 0.3546 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.8694 0.3405 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.8381 0.3562 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.8183 0.3506 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.8427 0.3474 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.8168 0.3647 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8741 0.3995 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.8978 0.4016 sec/batch
# Nearest to the: dispelled, infinitum, chubut, bamileke, exhortations, philadelphia, hanzei, dam,
# Nearest to about: curious, ghats, limassol, rossington, unforgettable, hardpoints, honduras, increase,
# Nearest to two: zero, andrewes, four, seven, dutton, three, five, annette,
# Nearest to they: ranged, margravate, endorsements, ancestral, specialization, shaoqi, slay, handedly,
# Nearest to th: century, sira, rd, kievan, cycles, oghuz, deceitful, bronfman,
# Nearest to d: theologian, physicist, frontiersman, mae, guglielmo, botanist, victoria, sociologist,
# Nearest to war: secede, imperialists, allies, wars, warfare, communists, congolese, trojan,
# Nearest to when: bolus, excalibur, incongruous, marcian, thetis, gundam, lode, conquers,
# Nearest to engineering: argumentation, confounded, flyweight, nanotechnology, tuong, technologies, renewable, iau,
# Nearest to stage: amputated, noticed, chef, gssps, blonde, millar, deluge, actors,
# Nearest to additional: deutsch, flit, humiliation, wcw, wikis, amps, aloud, anconia,
# Nearest to http: www, html, org, htm, com, edu, tutorials, archive,
# Nearest to taking: poset, breaker, awk, lilia, filesystem, vaughan, precipitates, froissart,
# Nearest to mean: antisymmetric, isn, convenient, computable, substituting, breaded, sample, exp,
# Nearest to cost: pace, beggars, signal, plasmodium, buttons, kilowatts, nigger, externally,
# Nearest to ice: stylistic, underwater, slugger, jaguars, vapor, pentafluoride, opportune, gauze,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.8988 0.3943 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.8377 0.3747 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.8192 0.3236 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.8403 0.3236 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.6984 0.3253 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.8292 0.3300 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.8452 0.3261 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.8141 0.3338 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.8376 0.0559 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.8236 0.3306 sec/batch
# Nearest to the: dispelled, infinitum, chubut, bamileke, shattering, eschewed, dam, philadelphia,
# Nearest to about: ghats, curious, rossington, limassol, watered, hardpoints, unforgettable, proclus,
# Nearest to two: zero, four, andrewes, three, five, seven, dutton, sig,
# Nearest to they: ranged, ancestral, endorsements, margravate, specialization, ganga, slay, seasonally,
# Nearest to th: century, sira, rd, cycles, kievan, bronfman, oghuz, deceitful,
# Nearest to d: theologian, physicist, botanist, mae, guglielmo, frontiersman, ardant, victoria,
# Nearest to war: imperialists, secede, allies, wars, communists, warfare, trojan, congolese,
# Nearest to when: bolus, incongruous, excalibur, marcian, gundam, thetis, macedonica, lode,
# Nearest to engineering: argumentation, confounded, nanotechnology, renewable, flyweight, tuong, arpa, fame,
# Nearest to stage: amputated, noticed, chef, blonde, gssps, millar, actors, heck,
# Nearest to additional: deutsch, flit, wcw, humiliation, amps, wikis, amperes, onshore,
# Nearest to http: www, html, org, htm, edu, com, tutorials, archive,
# Nearest to taking: poset, breaker, awk, precipitates, filesystem, lilia, froissart, vaughan,
# Nearest to mean: antisymmetric, isn, convenient, sample, substituting, computable, exp, districts,
# Nearest to cost: pace, signal, externally, incomes, thalamus, beggars, plasmodium, price,
# Nearest to ice: stylistic, underwater, jaguars, slugger, pole, vapor, opportune, pentafluoride,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7680 0.3330 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.7776 0.3303 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.7902 0.3591 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.7484 0.3293 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.7651 0.3532 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.7357 0.3833 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7855 0.3917 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.7847 0.4027 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.8093 0.3563 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.7181 0.3839 sec/batch
# Nearest to the: dispelled, infinitum, bamileke, chubut, shattering, eschewed, dam, philadelphia,
# Nearest to about: ghats, rossington, curious, limassol, hardpoints, proclus, watered, ucmp,
# Nearest to two: zero, andrewes, four, three, five, dutton, sig, seven,
# Nearest to they: ranged, ancestral, local, endorsements, reorganizing, margravate, specialization, ganga,
# Nearest to th: century, sira, rd, cycles, kievan, oghuz, bronfman, deceitful,
# Nearest to d: theologian, mae, guglielmo, frontiersman, physicist, botanist, ardant, ouverture,
# Nearest to war: imperialists, allies, wars, warfare, secede, communists, trojan, telekinetic,
# Nearest to when: bolus, incongruous, excalibur, marcian, gundam, thetis, lode, macedonica,
# Nearest to engineering: argumentation, nanotechnology, confounded, flyweight, tuong, renewable, physics, incorporates,
# Nearest to stage: amputated, noticed, blonde, gssps, actors, heck, chef, millar,
# Nearest to additional: deutsch, wcw, flit, humiliation, amps, wikis, onshore, minimised,
# Nearest to http: www, html, org, htm, com, edu, tutorials, shtml,
# Nearest to taking: poset, precipitates, ailment, awk, inhibitors, breaker, currency, lilia,
# Nearest to mean: isn, antisymmetric, sample, convenient, substituting, computable, districts, breaded,
# Nearest to cost: pace, price, externally, signal, incomes, beggars, pritchett, thalamus,
# Nearest to ice: stylistic, underwater, jaguars, slugger, opportune, pentafluoride, glaciology, pole,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.7314 0.3569 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.7098 0.3576 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.7022 0.3638 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.7442 0.4061 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.7691 0.4063 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.7403 0.4355 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.7469 0.3866 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.7975 0.3879 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.7267 0.4505 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.7321 0.3657 sec/batch
# Nearest to the: infinitum, dispelled, bamileke, chubut, shattering, philadelphia, eschewed, exhortations,
# Nearest to about: ghats, rossington, curious, watered, limassol, unforgettable, said, ucmp,
# Nearest to two: andrewes, zero, four, three, five, jun, explication, sig,
# Nearest to they: ranged, local, ancestral, specialization, margravate, endorsements, slay, reorganizing,
# Nearest to th: century, sira, rd, cycles, kievan, nd, bronfman, sennar,
# Nearest to d: theologian, frontiersman, guglielmo, mae, physicist, internationale, perutz, victoria,
# Nearest to war: imperialists, secede, allies, wars, warfare, communists, trojan, telekinetic,
# Nearest to when: bolus, incongruous, excalibur, marcian, thetis, acrylics, gundam, macedonica,
# Nearest to engineering: nanotechnology, renewable, argumentation, engineers, tuong, confounded, flyweight, arpa,
# Nearest to stage: amputated, noticed, blonde, gssps, actors, appearing, chef, millar,
# Nearest to additional: deutsch, wcw, flit, humiliation, wikis, amps, amperes, aloud,
# Nearest to http: www, html, org, htm, com, edu, shtml, tutorials,
# Nearest to taking: poset, currency, precipitates, breaker, inhibitors, awk, filesystem, ailment,
# Nearest to mean: isn, antisymmetric, sample, breaded, convenient, districts, nootka, computable,
# Nearest to cost: pace, price, plasmodium, externally, pritchett, beggars, attendees, incomes,
# Nearest to ice: stylistic, underwater, slugger, jaguars, vapor, pentafluoride, pole, octopussy,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.7426 0.3947 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.7982 0.3611 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.7709 0.3643 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.7315 0.3728 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.7595 0.3472 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.7229 0.3321 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.7566 0.3305 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.7466 0.3332 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.7675 0.3318 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.7426 0.3357 sec/batch
# Nearest to the: infinitum, bamileke, dispelled, chubut, shattering, exhortations, eschewed, dam,
# Nearest to about: ghats, curious, rossington, limassol, ucmp, watered, said, honduras,
# Nearest to two: andrewes, zero, four, three, explication, five, chamonix, dutton,
# Nearest to they: margravate, ranged, ancestral, slay, endeavoured, hardy, handedly, frankly,
# Nearest to th: century, sira, rd, kievan, nd, cycles, oghuz, bronfman,
# Nearest to d: theologian, guglielmo, frontiersman, internationale, ardant, perutz, victoria, mae,
# Nearest to war: imperialists, allies, wars, secede, warfare, communists, ii, gendarmerie,
# Nearest to when: bolus, excalibur, marcian, thetis, macedonica, acrylics, abolish, incongruous,
# Nearest to engineering: argumentation, renewable, confounded, nanotechnology, tuong, engineers, arpa, flyweight,
# Nearest to stage: amputated, noticed, actors, gssps, heck, appearing, blonde, millar,
# Nearest to additional: deutsch, wcw, flit, humiliation, amps, wikis, amperes, onshore,
# Nearest to http: www, html, org, htm, edu, com, shtml, archive,
# Nearest to taking: poset, currency, breaker, precipitates, faro, awk, francks, inhibitors,
# Nearest to mean: isn, antisymmetric, sample, convenient, breaded, computable, districts, shaktism,
# Nearest to cost: pace, plasmodium, price, thalamus, externally, hovering, incomes, vorpal,
# Nearest to ice: stylistic, jaguars, vapor, glaciology, underwater, pentafluoride, skeletal, slugger,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.7261 0.3464 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.6952 0.3857 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.7192 0.3566 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.7528 0.3575 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.7698 0.3590 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.7960 0.3529 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.8102 0.3509 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.7293 0.3499 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.7167 0.3512 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.7671 0.3483 sec/batch
# Nearest to the: infinitum, dispelled, bamileke, chubut, shattering, eschewed, dam, parlay,
# Nearest to about: rossington, ghats, limassol, honduras, ucmp, curious, hardpoints, unforgettable,
# Nearest to two: andrewes, zero, four, three, five, sig, dutton, chamonix,
# Nearest to they: margravate, ranged, frankly, ancestral, slay, endorsements, endeavoured, shaoqi,
# Nearest to th: century, sira, rd, oghuz, cycles, kievan, sennar, pittsfield,
# Nearest to d: theologian, frontiersman, ardant, internationale, ouverture, guglielmo, mae, victoria,
# Nearest to war: allies, imperialists, wars, secede, warfare, communists, ii, gendarmerie,
# Nearest to when: bolus, marcian, thetis, excalibur, acrylics, macedonica, incongruous, abolish,
# Nearest to engineering: argumentation, nanotechnology, tuong, confounded, renewable, engineers, arpa, flyweight,
# Nearest to stage: amputated, actors, noticed, heck, gssps, blonde, appearing, deprecating,
# Nearest to additional: deutsch, wcw, humiliation, flit, amps, wikis, onshore, amperes,
# Nearest to http: www, html, org, htm, edu, com, shtml, pub,
# Nearest to taking: poset, breaker, currency, ailment, awk, precipitates, froissart, kirwan,
# Nearest to mean: isn, sample, antisymmetric, convenient, deadpan, districts, breaded, nootka,
# Nearest to cost: pace, plasmodium, hovering, incomes, price, externally, vorpal, thalamus,
# Nearest to ice: stylistic, jaguars, glaciology, slugger, vapor, pentafluoride, guitarist, gauze,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.6718 0.3559 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.7189 0.3514 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.7178 0.3517 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.7278 0.3554 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.7400 0.3517 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.7301 0.3138 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.7179 0.3755 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.6990 0.3746 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.6735 0.3437 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.6510 0.3782 sec/batch
# Nearest to the: dispelled, infinitum, bamileke, shattering, chubut, parlay, exhortations, eschewed,
# Nearest to about: rossington, ghats, limassol, curious, said, unforgettable, ucmp, proclus,
# Nearest to two: zero, andrewes, three, four, five, jun, sig, dutton,
# Nearest to they: frankly, slay, ancestral, margravate, ranged, endorsements, endeavoured, blinking,
# Nearest to th: century, rd, sira, oghuz, cycles, sennar, isidore, kingship,
# Nearest to d: theologian, frontiersman, internationale, ardant, physician, victoria, perutz, botanist,
# Nearest to war: imperialists, wars, allies, secede, warfare, ii, fluctuation, vallabhbhai,
# Nearest to when: bolus, thetis, acrylics, marcian, incongruous, macedonica, gundam, abolish,
# Nearest to engineering: nanotechnology, argumentation, engineers, tuong, renewable, arpa, confounded, physics,
# Nearest to stage: amputated, actors, noticed, heck, gssps, blonde, appearing, deprecating,
# Nearest to additional: wcw, deutsch, flit, humiliation, aloud, amps, wikis, linebackers,
# Nearest to http: www, html, org, htm, edu, com, shtml, pub,
# Nearest to taking: poset, ailment, awk, precipitates, inhibitors, breaker, froissart, currency,
# Nearest to mean: isn, sample, antisymmetric, convenient, districts, kingman, formalist, substituting,
# Nearest to cost: pace, price, hovering, pritchett, hollywood, plasmodium, externally, incomes,
# Nearest to ice: stylistic, jaguars, glaciology, pentafluoride, slugger, guitarist, vapor, opportune,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.6882 0.3994 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.6379 0.3803 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.6939 0.3278 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.7227 0.3288 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.7199 0.3292 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.6954 0.3334 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.6076 0.3723 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.6481 0.3327 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.6642 0.3434 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.6573 0.3468 sec/batch
# Nearest to the: infinitum, dispelled, shattering, bamileke, chubut, eschewed, dam, philadelphia,
# Nearest to about: rossington, ghats, curious, limassol, ucmp, honduras, hardpoints, hacking,
# Nearest to two: zero, andrewes, three, five, four, sig, jun, explication,
# Nearest to they: frankly, slay, ancestral, margravate, handedly, endorsements, blinking, ranged,
# Nearest to th: century, rd, sira, nd, oghuz, pittsfield, cycles, kingship,
# Nearest to d: frontiersman, internationale, theologian, perutz, guglielmo, ardant, oral, mae,
# Nearest to war: imperialists, wars, allies, secede, ii, warfare, fluctuation, redevelop,
# Nearest to when: bolus, thetis, marcian, acrylics, macedonica, incongruous, gundam, excalibur,
# Nearest to engineering: nanotechnology, tuong, arpa, engineers, renewable, argumentation, physics, emory,
# Nearest to stage: amputated, actors, heck, gssps, noticed, polytechnics, deprecating, appearing,
# Nearest to additional: wcw, deutsch, humiliation, flit, aloud, amps, wikis, seaport,
# Nearest to http: www, html, org, htm, com, edu, shtml, gov,
# Nearest to taking: poset, ailment, precipitates, inhibitors, breaker, currency, froissart, awk,
# Nearest to mean: isn, sample, antisymmetric, convenient, districts, kingman, breaded, substituting,
# Nearest to cost: pace, hovering, externally, pritchett, plasmodium, price, hollywood, incomes,
# Nearest to ice: stylistic, jaguars, slugger, vapor, glaciology, pentafluoride, guitarist, carbonates,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.6775 0.3665 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.6870 0.3305 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.6556 0.3349 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.7085 0.3284 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.6904 0.3286 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.6480 0.3282 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.7060 0.3321 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.7063 0.3557 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6748 0.3930 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.6772 0.3863 sec/batch
# Nearest to the: infinitum, dispelled, bamileke, shattering, chubut, eschewed, exhortations, creeds,
# Nearest to about: rossington, hacking, honduras, apathy, ghats, curious, ucmp, limassol,
# Nearest to two: andrewes, zero, three, four, jun, five, dutton, sig,
# Nearest to they: frankly, ancestral, slay, margravate, endorsements, endeavoured, handedly, subliminal,
# Nearest to th: century, rd, sira, nd, isidore, kingship, sennar, oghuz,
# Nearest to d: frontiersman, theologian, internationale, ardant, perutz, guglielmo, victoria, mae,
# Nearest to war: imperialists, wars, allies, secede, ii, warfare, wartime, communists,
# Nearest to when: bolus, thetis, marcian, acrylics, gundam, excalibur, macedonica, snout,
# Nearest to engineering: arpa, nanotechnology, engineers, tuong, argumentation, renewable, confounded, fame,
# Nearest to stage: amputated, actors, appearing, gssps, deprecating, polytechnics, heck, frigates,
# Nearest to additional: wcw, deutsch, humiliation, flit, amps, wikis, governmental, own,
# Nearest to http: www, html, org, htm, com, edu, shtml, pub,
# Nearest to taking: poset, precipitates, currency, vaughan, awk, ailment, breaker, axioms,
# Nearest to mean: isn, sample, antisymmetric, breaded, presaging, kingman, nootka, deadpan,
# Nearest to cost: pace, attendees, plasmodium, hovering, pritchett, hollywood, vorpal, price,
# Nearest to ice: jaguars, slugger, stylistic, guitarist, glaciology, entrepreneur, vapor, charlie,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.6861 0.3639 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.6666 0.3814 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.6795 0.3537 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.6816 0.3578 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.6932 0.3486 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.7072 0.3912 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.6724 0.3555 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.6368 0.3831 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.6367 0.3574 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.6935 0.3593 sec/batch
# Nearest to the: infinitum, dispelled, bamileke, chubut, dam, shattering, exhortations, eschewed,
# Nearest to about: honduras, rossington, ghats, ucmp, hacking, apathy, limassol, curious,
# Nearest to two: andrewes, zero, three, four, five, sig, jun, chamonix,
# Nearest to they: frankly, slay, margravate, ancestral, hardy, endorsements, coalesce, endeavoured,
# Nearest to th: century, rd, sira, kingship, sennar, nd, isidore, oghuz,
# Nearest to d: frontiersman, internationale, theologian, ardant, perutz, victoria, guglielmo, kirchhoff,
# Nearest to war: imperialists, wars, allies, secede, ii, warfare, hanko, communists,
# Nearest to when: bolus, acrylics, marcian, thetis, macedonica, pillar, arturo, incongruous,
# Nearest to engineering: nanotechnology, tuong, arpa, engineers, renewable, argumentation, confounded, emory,
# Nearest to stage: actors, amputated, deprecating, appearing, heck, gssps, polytechnics, frigates,
# Nearest to additional: wcw, deutsch, humiliation, flit, amps, seaport, governmental, own,
# Nearest to http: www, html, org, htm, com, shtml, edu, gov,
# Nearest to taking: poset, precipitates, currency, ailment, axioms, breaker, vaughan, froissart,
# Nearest to mean: isn, sample, antisymmetric, convenient, presaging, substituting, breaded, entropy,
# Nearest to cost: pace, plasmodium, hovering, price, attendees, incomes, vorpal, externally,
# ...
# Nearest to engineering: nanotechnology, engineers, arpa, reverse, technology, fields, cuny, integrative,
# Nearest to stage: actors, deprecating, staged, fetuses, frigates, emptive, appearing, polytechnics,
# Nearest to additional: wcw, governmental, voices, dots, humiliation, isdn, harmoniously, smoot,
# Nearest to http: www, com, org, shtml, html, htm, edu, geocities,
# Nearest to taking: poset, currency, precipitates, ailment, minuteman, zurich, axioms, optional,
# Nearest to mean: sample, isn, variance, entropy, consistently, kingman, gini, nowhere,
# Nearest to cost: plasmodium, price, hovering, trillion, attendees, hollywood, norfolk, bacardi,
# Nearest to ice: sj, hockey, glaciology, hungarian, jaguars, pole, carbonates, ute,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.5095 0.3572 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.5103 0.3431 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.5200 0.3424 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.5333 0.3403 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.5471 0.3416 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.5717 0.3426 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.5442 0.3493 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.5471 0.3402 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.5574 0.3519 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.5628 0.3452 sec/batch
# Nearest to the: dispelled, infinitum, surreptitiously, bamileke, josaphat, scalars, irbm, krueger,
# Nearest to about: sixteen, ucmp, essene, freeserve, condemned, rossington, essences, copycat,
# Nearest to two: jun, zero, antiquity, festal, andrewes, sig, unreleased, three,
# Nearest to they: margravate, hardy, lup, slay, coalesce, mrsi, ewa, redefinition,
# Nearest to th: century, nd, rd, centuries, kingship, tenth, codification, sennar,
# Nearest to d: internationale, theologian, frontiersman, tte, ardant, patches, perutz, icons,
# Nearest to war: ii, wars, secede, imperialists, exporter, wartime, napoleonic, ending,
# Nearest to when: acrylics, intervening, bolus, fades, rebuffed, childless, zamboanga, marcian,
# Nearest to engineering: nanotechnology, engineers, reverse, arpa, fields, integrative, cuny, tuong,
# Nearest to stage: actors, deprecating, frigates, staged, fetuses, polytechnics, emptive, mcbeal,
# Nearest to additional: wcw, governmental, dots, humiliation, smoot, voices, reviewers, isdn,
# Nearest to http: www, org, html, com, shtml, htm, edu, geocities,
# Nearest to taking: poset, currency, precipitates, zurich, minuteman, kirwan, axioms, walpole,
# Nearest to mean: sample, isn, variance, consistently, entropy, gini, nowhere, kingman,
# Nearest to cost: plasmodium, hovering, price, hollywood, trillion, noncommercial, attendees, operationally,
# Nearest to ice: glaciology, sj, hockey, hungarian, carbonates, pole, jaguars, ute,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.5361 0.3478 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.5474 0.3407 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.5117 0.3408 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.5210 0.3435 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.6031 0.3451 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.5209 0.3457 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.6269 0.3447 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.5766 0.3425 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.5968 0.3426 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.5170 0.3443 sec/batch
# Nearest to the: dispelled, infinitum, josaphat, surreptitiously, irbm, bamileke, chubut, krueger,
# Nearest to about: sixteen, ucmp, essene, condemned, rossington, essences, freeserve, hacking,
# Nearest to two: zero, jun, unreleased, sig, genuineness, festal, ageing, antiquity,
# Nearest to they: margravate, lup, say, coalesce, ewa, redefinition, ezln, sell,
# Nearest to th: century, nd, rd, centuries, kingship, tenth, sennar, pittsfield,
# Nearest to d: theologian, internationale, ardant, tte, frontiersman, italian, mae, patches,
# Nearest to war: ii, wars, imperialists, cold, exporter, secede, world, wartime,
# Nearest to when: acrylics, intervening, rebuffed, bolus, marcian, fades, zamboanga, childless,
# Nearest to engineering: nanotechnology, engineers, reverse, arpa, army, integrative, cuny, fields,
# Nearest to stage: actors, deprecating, frigates, fetuses, appearing, polytechnics, staged, emptive,
# Nearest to additional: wcw, smoot, governmental, humiliation, reviewers, harmoniously, dots, voices,
# Nearest to http: www, org, com, html, htm, shtml, edu, geocities,
# Nearest to taking: poset, currency, precipitates, kirwan, walpole, ailment, zurich, minuteman,
# Nearest to mean: sample, isn, variance, entropy, consistently, average, gini, kingman,
# Nearest to cost: plasmodium, price, hovering, hollywood, attendees, trillion, bacardi, mckernan,
# Nearest to ice: sj, hungarian, glaciology, hockey, jaguars, pole, carbonates, ute,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.4963 0.3510 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.5646 0.3417 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.4540 0.3457 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.5430 0.3403 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.5394 0.3408 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.5351 0.3418 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.5710 0.1639 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.5027 0.3404 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.5155 0.3415 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.5359 0.3425 sec/batch
# Nearest to the: dispelled, infinitum, irbm, josaphat, scalars, surreptitiously, krueger, tawi,
# Nearest to about: sixteen, ucmp, essene, rossington, essences, condemned, freeserve, sequestration,
# Nearest to two: zero, jun, visser, sig, three, unreleased, ageing, festal,
# Nearest to they: margravate, lup, say, coalesce, ezln, quit, slay, cladograms,
# Nearest to th: century, nd, rd, centuries, kingship, tenth, sennar, codification,
# Nearest to d: theologian, internationale, tte, ardant, frontiersman, italian, mae, composer,
# Nearest to war: ii, imperialists, wars, secede, wartime, exporter, cold, world,
# Nearest to when: acrylics, intervening, rebuffed, bolus, fades, childless, marcian, ahaziah,
# Nearest to engineering: nanotechnology, engineers, arpa, reverse, cuny, fields, integrative, biomedical,
# Nearest to stage: actors, deprecating, frigates, fetuses, overstretched, emptive, polytechnics, appearing,
# Nearest to additional: wcw, governmental, smoot, isdn, humiliation, reviewers, voices, dots,
# Nearest to http: www, org, com, html, shtml, htm, edu, geocities,
# Nearest to taking: poset, currency, precipitates, ailment, zurich, walpole, sylvester, minuteman,
# Nearest to mean: sample, isn, variance, entropy, average, consistently, sine, gini,
# Nearest to cost: price, plasmodium, hovering, hollywood, bacardi, attendees, marginal, trillion,
# Nearest to ice: glaciology, hungarian, sj, hockey, jaguars, pole, carbonates, ute,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.5219 0.3441 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.4910 0.3411 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.5084 0.3408 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.4847 0.3397 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.5387 0.3391 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.5134 0.3408 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.5488 0.3419 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.4580 0.3425 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.4931 0.3424 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.4770 0.3436 sec/batch
# Nearest to the: dispelled, infinitum, scalars, josaphat, surreptitiously, bamileke, krueger, tawi,
# Nearest to about: sixteen, ucmp, essene, freeserve, essences, copycat, ange, sequestration,
# Nearest to two: zero, jun, three, sig, four, five, visser, ageing,
# Nearest to they: margravate, lup, say, quit, cladograms, mrsi, coalesce, ezln,
# Nearest to th: century, nd, rd, kingship, centuries, codification, tenth, pittsfield,
# Nearest to d: internationale, theologian, tte, mae, patches, perutz, frontiersman, ardant,
# Nearest to war: ii, wars, world, exporter, wartime, cold, imperialists, secede,
# Nearest to when: acrylics, intervening, rebuffed, fades, bolus, marcian, childless, zamboanga,
# Nearest to engineering: nanotechnology, engineers, arpa, reverse, fields, biomedical, integrative, cuny,
# Nearest to stage: actors, deprecating, fetuses, frigates, polytechnics, staged, emptive, overstretched,
# Nearest to additional: wcw, voices, smoot, governmental, isdn, humiliation, reviewers, dots,
# Nearest to http: www, com, org, htm, html, shtml, edu, geocities,
# Nearest to taking: poset, precipitates, currency, zurich, ailment, sleep, minuteman, walpole,
# Nearest to mean: sample, isn, variance, entropy, average, consistently, sine, gini,
# Nearest to cost: plasmodium, price, hovering, hollywood, marginal, feudal, mckernan, norfolk,
# Nearest to ice: glaciology, sj, hungarian, hockey, carbonates, jaguars, pole, extraterrestrial,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.4525 0.3520 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.4906 0.3440 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.5280 0.3440 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.4957 0.3441 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.5016 0.3415 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.5647 0.3424 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.5282 0.3424 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.5197 0.3415 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.5149 0.3434 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.5194 0.3423 sec/batch
# Nearest to the: dispelled, infinitum, scalars, josaphat, krueger, surreptitiously, creeds, bamileke,
# Nearest to about: sixteen, ucmp, essene, copycat, essences, freeserve, apathy, rossington,
# Nearest to two: zero, jun, three, unreleased, visser, festal, sig, antiquity,
# Nearest to they: margravate, lup, mrsi, cladograms, coalesce, redefinition, say, quit,
# Nearest to th: century, nd, rd, centuries, kingship, codification, tenth, harmonicist,
# Nearest to d: internationale, theologian, ardant, tte, patches, mae, frontiersman, braid,
# Nearest to war: ii, wars, exporter, wartime, imperialists, cold, secede, world,
# Nearest to when: acrylics, intervening, fades, rebuffed, bolus, childless, zamboanga, marcian,
# Nearest to engineering: engineers, nanotechnology, reverse, arpa, biomedical, cuny, tuong, technology,
# Nearest to stage: actors, deprecating, fetuses, frigates, staged, polytechnics, appearing, emptive,
# Nearest to additional: wcw, governmental, voices, smoot, isdn, humiliation, dots, reviewers,
# Nearest to http: www, org, htm, com, html, shtml, edu, geocities,
# Nearest to taking: poset, currency, precipitates, sleep, zurich, axioms, kirwan, minuteman,
# Nearest to mean: sample, isn, variance, entropy, consistently, average, sine, nowhere,
# Nearest to cost: plasmodium, price, marginal, hovering, hollywood, feudal, attendees, norfolk,
# Nearest to ice: hungarian, sj, hockey, glaciology, carbonates, jaguars, pole, ute,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.5703 0.3464 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.5006 0.3389 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.5154 0.3408 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.5315 0.3406 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.5501 0.3399 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.5348 0.3426 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.5136 0.3406 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.5099 0.3444 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.4881 0.3436 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.5014 0.3418 sec/batch
# Nearest to the: infinitum, dispelled, scalars, surreptitiously, josaphat, tawi, krueger, bamileke,
# Nearest to about: sixteen, ucmp, essene, freeserve, copycat, ange, essences, fifty,
# Nearest to two: zero, three, four, jun, five, visser, sig, genuineness,
# Nearest to they: margravate, lup, coalesce, sell, cladograms, redefinition, mrsi, ewa,
# Nearest to th: century, nd, rd, kingship, centuries, codification, pittsfield, sennar,
# Nearest to d: internationale, theologian, patches, ardant, tte, mae, sniping, frontiersman,
# Nearest to war: ii, exporter, wars, wartime, imperialists, cold, secede, world,
# Nearest to when: acrylics, intervening, fades, zamboanga, childless, bolus, rebuffed, marcian,
# Nearest to engineering: nanotechnology, engineers, arpa, reverse, biomedical, cuny, tuong, heywood,
# Nearest to stage: actors, deprecating, fetuses, frigates, overstretched, emptive, mcbeal, polytechnics,
# Nearest to additional: wcw, governmental, humiliation, isdn, smoot, voices, reviewers, dots,
# Nearest to http: www, org, com, html, htm, shtml, edu, geocities,
# Nearest to taking: poset, currency, precipitates, zurich, sleep, kirwan, axioms, walpole,
# Nearest to mean: sample, variance, isn, entropy, average, consistently, sine, gini,
# Nearest to cost: plasmodium, price, hovering, marginal, hollywood, mckernan, lexical, trillion,
# Nearest to ice: hungarian, sj, hockey, glaciology, carbonates, pole, jaguars, forcing,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.5571 0.3456 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.5226 0.3421 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.5968 0.3396 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.5908 0.3385 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.5658 0.3341 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.5411 0.3372 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.4634 0.3342 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.5162 0.3354 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.4300 0.3352 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.5412 0.3373 sec/batch
# Nearest to the: dispelled, infinitum, scalars, krueger, surreptitiously, josaphat, creeds, chubut,
# Nearest to about: sixteen, ucmp, freeserve, essences, essene, copycat, nist, ange,
# Nearest to two: zero, sig, jun, visser, three, ageing, genuineness, unreleased,
# Nearest to they: margravate, lup, say, coalesce, mrsi, cladograms, stalks, ezln,
# Nearest to th: century, nd, rd, centuries, kingship, codification, pittsfield, harmonicist,
# Nearest to d: internationale, theologian, ardant, italian, mae, physician, frontiersman, composer,
# Nearest to war: ii, exporter, wars, cold, world, wartime, imperialists, allies,
# Nearest to when: acrylics, intervening, fades, rebuffed, zamboanga, bolus, marcian, childless,
# Nearest to engineering: nanotechnology, engineers, arpa, biomedical, reverse, heywood, fields, tuong,
# Nearest to stage: actors, deprecating, fetuses, mcbeal, frigates, overstretched, stages, staged,
# Nearest to additional: wcw, governmental, humiliation, smoot, voices, isdn, dots, reviewers,
# Nearest to http: www, org, com, htm, html, edu, shtml, geocities,
# Nearest to taking: poset, currency, precipitates, kirwan, sleep, zurich, walpole, sylvester,
# Nearest to mean: sample, variance, average, isn, entropy, sine, consistently, gini,
# Nearest to cost: marginal, price, plasmodium, feudal, hovering, exceed, restricted, lexical,
# Nearest to ice: hungarian, sj, glaciology, hockey, carbonates, jaguars, forcing, pole,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.5263 0.3415 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.5176 0.3342 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
